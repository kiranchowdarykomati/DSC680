# %% [markdown]
# <a href="https://colab.research.google.com/github/kiranchowdarykomati/DSC680/blob/main/Project%202/DSC_680_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
os.chdir('/content/drive/MyDrive/Covid19-dataset')
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Covid19-dataset

# %%
from IPython import display
import os
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random as python_random
import tensorflow as tf
import seaborn as sns
import math
from sklearn.metrics import classification_report, confusion_matrix,plot_confusion_matrix

np.random.seed(42)
tf.random.set_seed(42)

# %%
# ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from PIL import ImageFilter

height, width = 224, 224
batch_size=64


def generate_data(DIR):
    datagen = ImageDataGenerator(rescale=1./255.)
    
    generator = datagen.flow_from_directory(
        DIR,
        batch_size=batch_size,
        shuffle=True,
        seed=42,
        class_mode='binary',
        target_size=(height, width),
        classes={'Normal': 0, 'Viral Pneumonia': 1,'Covid': 2}
    )
    return generator

TRAINING_DIR = '/content/drive/MyDrive/Covid19-dataset/train'
TESTING_DIR = '/content/drive/MyDrive/Covid19-dataset/test'

train_generator = generate_data(TRAINING_DIR)
test_generator = generate_data(TESTING_DIR)

total_image = np.concatenate([train_generator.labels,test_generator.labels])

print('\n\n',{'Normal_cases':len(np.where(total_image==0)[0]),
      'Viral_Pneumonia_cases':len(np.where(total_image==1)[0]),
             'Covid_cases':len(np.where(total_image==2)[0])})
# Out:
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.
#
#
#  {'Normal_cases': 90, 'Viral_Pneumonia_cases': 90, 'Covid_cases': 137}

# %%
df = pd.DataFrame (total_image, columns = ['labels'])
df.value_counts()
df['labels'].value_counts().plot(kind='bar', figsize=(7, 6), rot=0)
plt.xlabel("label", labelpad=14)
plt.ylabel("Counts", labelpad=14)
plt.title("Count of People with labels", y=1.02);

# %%
def image_plot(generator,image_numbers):
    img_feature = generator[0][0][:image_numbers]
    img_label = generator[0][1][:image_numbers]

    plt.figure(figsize=(20, 15))
    for i in range(image_numbers):
        ax = plt.subplot(math.ceil(image_numbers/4),4, i + 1)
        plt.imshow(img_feature[i])
        plt.title("Normal" if img_label[i] == 0 else "Viral Pneumonia" if img_label[i] == 1 else "Covid")
        plt.axis("off")

image_plot(train_generator,15)

# %%
from tensorflow.keras.layers.experimental import preprocessing

tf.keras.backend.clear_session()
input_shape = (height, width, 3)
base_model = tf.keras.applications.vgg16.VGG16(
    weights='imagenet', 
    include_top=False,
    input_shape=input_shape
)
base_model.trainable = False

model_vgg16 = tf.keras.Sequential()
model_vgg16.add(base_model)
model_vgg16.add(tf.keras.layers.GlobalAveragePooling2D())
model_vgg16.add(tf.keras.layers.Flatten())
model_vgg16.add(tf.keras.layers.Dense(256, activation='relu'))
model_vgg16.add(tf.keras.layers.Dropout(0.5))
model_vgg16.add(tf.keras.layers.Dense(256, activation='relu'))
model_vgg16.add(tf.keras.layers.Dropout(0.5))
model_vgg16.add(tf.keras.layers.Dense(3, activation='softmax'))

model_vgg16.compile(loss='SparseCategoricalCrossentropy', 
              optimizer=tf.keras.optimizers.Adam(0.001),
              metrics=['acc'])
model_vgg16.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 14,912,579
# Trainable params: 197,891
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('model/vgg16_best.h5', monitor='acc', verbose=1, mode='max',save_best_only=True)
early = tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode="min",restore_best_weights=True, patience=5)

callbacks_list = [checkpoint,early]

history = model_vgg16.fit(
        train_generator,
        validation_data = test_generator,
        epochs=20, 
        shuffle=False, 
        verbose=True,
        callbacks=callbacks_list)
# Out:
# Epoch 1/20
# 4/4 [==============================] - ETA: 0s - loss: 1.2078 - acc: 0.3865
# Epoch 1: acc improved from -inf to 0.38645, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 193s 51s/step - loss: 1.2078 - acc: 0.3865 - val_loss: 1.0450 - val_acc: 0.3939
# Epoch 2/20
# 4/4 [==============================] - ETA: 0s - loss: 1.1162 - acc: 0.4343
# Epoch 2: acc improved from 0.38645 to 0.43426, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 170s 44s/step - loss: 1.1162 - acc: 0.4343 - val_loss: 0.9682 - val_acc: 0.3939
# Epoch 3/20
# 4/4 [==============================] - ETA: 0s - loss: 0.9845 - acc: 0.5219
# Epoch 3: acc improved from 0.43426 to 0.52191, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 172s 45s/step - loss: 0.9845 - acc: 0.5219 - val_loss: 0.8984 - val_acc: 0.6515
# Epoch 4/20
# 4/4 [==============================] - ETA: 0s - loss: 0.9071 - acc: 0.5339
# Epoch 4: acc improved from 0.52191 to 0.53386, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 172s 45s/step - loss: 0.9071 - acc: 0.5339 - val_loss: 0.8215 - val_acc: 0.7424
# Epoch 5/20
# 4/4 [==============================] - ETA: 0s - loss: 0.8382 - acc: 0.6414
# Epoch 5: acc improved from 0.53386 to 0.64143, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 171s 45s/step - loss: 0.8382 - acc: 0.6414 - val_loss: 0.7378 - val_acc: 0.7879
# Epoch 6/20
# 4/4 [==============================] - ETA: 0s - loss: 0.7282 - acc: 0.6853
# Epoch 6: acc improved from 0.64143 to 0.68526, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 170s 44s/step - loss: 0.7282 - acc: 0.6853 - val_loss: 0.6659 - val_acc: 0.7879
# Epoch 7/20
# 4/4 [==============================] - ETA: 0s - loss: 0.7159 - acc: 0.7251
# Epoch 7: acc improved from 0.68526 to 0.72510, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 172s 45s/step - loss: 0.7159 - acc: 0.7251 - val_loss: 0.6015 - val_acc: 0.8333
# Epoch 8/20
# 4/4 [==============================] - ETA: 0s - loss: 0.6096 - acc: 0.7888
# Epoch 8: acc improved from 0.72510 to 0.78884, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 173s 45s/step - loss: 0.6096 - acc: 0.7888 - val_loss: 0.5360 - val_acc: 0.8788
# Epoch 9/20
# 4/4 [==============================] - ETA: 0s - loss: 0.6025 - acc: 0.7410
# Epoch 9: acc did not improve from 0.78884
# 4/4 [==============================] - 172s 45s/step - loss: 0.6025 - acc: 0.7410 - val_loss: 0.4911 - val_acc: 0.8939
# Epoch 10/20
# 4/4 [==============================] - ETA: 0s - loss: 0.5317 - acc: 0.7849
# Epoch 10: acc did not improve from 0.78884
# 4/4 [==============================] - 172s 45s/step - loss: 0.5317 - acc: 0.7849 - val_loss: 0.4424 - val_acc: 0.8939
# Epoch 11/20
# 4/4 [==============================] - ETA: 0s - loss: 0.5282 - acc: 0.7849
# Epoch 11: acc did not improve from 0.78884
# 4/4 [==============================] - 171s 44s/step - loss: 0.5282 - acc: 0.7849 - val_loss: 0.4104 - val_acc: 0.8939
# Epoch 12/20
# 4/4 [==============================] - ETA: 0s - loss: 0.4855 - acc: 0.8167
# Epoch 12: acc improved from 0.78884 to 0.81673, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 173s 45s/step - loss: 0.4855 - acc: 0.8167 - val_loss: 0.3815 - val_acc: 0.9091
# Epoch 13/20
# 4/4 [==============================] - ETA: 0s - loss: 0.4760 - acc: 0.8048
# Epoch 13: acc did not improve from 0.81673
# 4/4 [==============================] - 173s 45s/step - loss: 0.4760 - acc: 0.8048 - val_loss: 0.3875 - val_acc: 0.8333
# Epoch 14/20
# 4/4 [==============================] - ETA: 0s - loss: 0.4468 - acc: 0.8406
# Epoch 14: acc improved from 0.81673 to 0.84064, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 172s 45s/step - loss: 0.4468 - acc: 0.8406 - val_loss: 0.3472 - val_acc: 0.9091
# Epoch 15/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3912 - acc: 0.8645
# Epoch 15: acc improved from 0.84064 to 0.86454, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 170s 44s/step - loss: 0.3912 - acc: 0.8645 - val_loss: 0.3231 - val_acc: 0.9242
# Epoch 16/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3547 - acc: 0.8964
# Epoch 16: acc improved from 0.86454 to 0.89641, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 170s 44s/step - loss: 0.3547 - acc: 0.8964 - val_loss: 0.3338 - val_acc: 0.8485
# Epoch 17/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3298 - acc: 0.9004
# Epoch 17: acc improved from 0.89641 to 0.90040, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 172s 45s/step - loss: 0.3298 - acc: 0.9004 - val_loss: 0.2908 - val_acc: 0.9091
# Epoch 18/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3037 - acc: 0.9004
# Epoch 18: acc did not improve from 0.90040
# 4/4 [==============================] - 171s 44s/step - loss: 0.3037 - acc: 0.9004 - val_loss: 0.2765 - val_acc: 0.9242
# Epoch 19/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3144 - acc: 0.9084
# Epoch 19: acc improved from 0.90040 to 0.90837, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 171s 44s/step - loss: 0.3144 - acc: 0.9084 - val_loss: 0.2925 - val_acc: 0.8333
# Epoch 20/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2935 - acc: 0.8884
# Epoch 20: acc did not improve from 0.90837
# 4/4 [==============================] - 171s 44s/step - loss: 0.2935 - acc: 0.8884 - val_loss: 0.2791 - val_acc: 0.8788

# %%
# plot learning curve
def plot_learning_curve(history):
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(len(acc))

    plt.plot(epochs, acc, label='training acc')
    plt.plot(epochs, val_acc, label='validation acc')
    plt.legend();
    plt.figure();

    plt.plot(epochs, loss, label='training loss')
    plt.plot(epochs, val_loss, label='validation loss')
    plt.legend();

plot_learning_curve(history)

# %%
train_result = model_vgg16.evaluate(train_generator)
test_result = model_vgg16.evaluate(test_generator)

no_augmented_df = pd.DataFrame(zip(train_result,test_result),columns=['Train','Val'],index=['Loss','Acc'])
no_augmented_df
# Out:
# 4/4 [==============================] - 136s 33s/step - loss: 0.2134 - acc: 0.9203
# 2/2 [==============================] - 35s 1s/step - loss: 0.2791 - acc: 0.8788
#          Train       Val
# Loss  0.213421  0.279091
# Acc   0.920319  0.878788

# %%
# Testing Confusion Matrix
ytest = np.array([])
xtest = []

for i in range(math.ceil(len(test_generator.classes)/batch_size)):
    xtest.append(test_generator[i][0]) 
    ytest= np.concatenate((ytest,test_generator[i][-1])) 
    
xtest = np.concatenate((xtest),axis=0)

ypred_prob =model_vgg16.predict(xtest)
ypred = np.argmax(ypred_prob,axis=1)

plt.figure(figsize=(6, 6))
hm = sns.heatmap(confusion_matrix(ytest,ypred), annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False,
            xticklabels=['Normal','Viral Penumonia','Covid'],yticklabels=['Normal','Viral Penumonia','Covid'])  
hm.set(xlabel='Predicted_labels')
hm.set(ylabel='True_labels')
print(classification_report(ytest,ypred))
# Out:
# 3/3 [==============================] - 33s 9s/step
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.70      0.78        20
#          1.0       0.75      0.90      0.82        20
#          2.0       1.00      1.00      1.00        26
#
#     accuracy                           0.88        66
#    macro avg       0.88      0.87      0.87        66
# weighted avg       0.89      0.88      0.88        66

# %%
#Extract wrong classification index
wrong_pred = np.where(ypred!=ytest)[0]

plt.figure(figsize=(20, 15))
for i,n in enumerate(wrong_pred):
    ax = plt.subplot(math.ceil(len(wrong_pred)/4),4, i + 1)
    plt.imshow(xtest[n])
    plt.title("Normal" if ypred[n] == 0 else "Viral Pneumonia" if ypred[n] == 1 else "Covid",color='r')
    plt.axis("off")

# %%
# Adding image augmentation
def generate_data_augmented(DIR):
    datagen = ImageDataGenerator(
        rescale=1./255.,
        zoom_range=0.1,
        rotation_range=20,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True
    )
    generator = datagen.flow_from_directory(
        TRAINING_DIR,
        batch_size=batch_size,
        seed=42,
        class_mode='binary',
        target_size=(height, width),
        classes={'Normal': 0, 'Viral Pneumonia': 1,'Covid': 2}
    )
    return generator

aug_train_generator = generate_data_augmented(TRAINING_DIR)

image_plot(aug_train_generator,15)
# Out:
# Found 251 images belonging to 3 classes.

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('model/vgg16_best.h5', monitor='acc', verbose=1, mode='max',save_best_only=True)
early = tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode="min",restore_best_weights=True, patience=10)

callbacks_list = [checkpoint,early]

history = model_vgg16.fit(
        aug_train_generator,
        validation_data = test_generator,
        epochs=20, 
        shuffle=False, 
        verbose=True,
        callbacks=callbacks_list)
# Out:
# Epoch 1/20
# 4/4 [==============================] - ETA: 0s - loss: 0.4016 - acc: 0.8446
# Epoch 1: acc improved from -inf to 0.84462, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 175s 45s/step - loss: 0.4016 - acc: 0.8446 - val_loss: 0.2715 - val_acc: 0.8788
# Epoch 2/20
# 4/4 [==============================] - ETA: 0s - loss: 0.4309 - acc: 0.8088
# Epoch 2: acc did not improve from 0.84462
# 4/4 [==============================] - 173s 45s/step - loss: 0.4309 - acc: 0.8088 - val_loss: 0.2633 - val_acc: 0.9394
# Epoch 3/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3896 - acc: 0.8526
# Epoch 3: acc improved from 0.84462 to 0.85259, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 173s 45s/step - loss: 0.3896 - acc: 0.8526 - val_loss: 0.2664 - val_acc: 0.8636
# Epoch 4/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3272 - acc: 0.8924
# Epoch 4: acc improved from 0.85259 to 0.89243, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 173s 45s/step - loss: 0.3272 - acc: 0.8924 - val_loss: 0.2578 - val_acc: 0.9091
# Epoch 5/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3150 - acc: 0.8964
# Epoch 5: acc improved from 0.89243 to 0.89641, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 173s 45s/step - loss: 0.3150 - acc: 0.8964 - val_loss: 0.2469 - val_acc: 0.9394
# Epoch 6/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3073 - acc: 0.9044
# Epoch 6: acc improved from 0.89641 to 0.90438, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 175s 45s/step - loss: 0.3073 - acc: 0.9044 - val_loss: 0.2343 - val_acc: 0.9091
# Epoch 7/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2934 - acc: 0.8725
# Epoch 7: acc did not improve from 0.90438
# 4/4 [==============================] - 174s 45s/step - loss: 0.2934 - acc: 0.8725 - val_loss: 0.2227 - val_acc: 0.9091
# Epoch 8/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3009 - acc: 0.8805
# Epoch 8: acc did not improve from 0.90438
# 4/4 [==============================] - 174s 45s/step - loss: 0.3009 - acc: 0.8805 - val_loss: 0.2288 - val_acc: 0.9394
# Epoch 9/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3497 - acc: 0.8685
# Epoch 9: acc did not improve from 0.90438
# 4/4 [==============================] - 173s 45s/step - loss: 0.3497 - acc: 0.8685 - val_loss: 0.2250 - val_acc: 0.9242
# Epoch 10/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3269 - acc: 0.8845
# Epoch 10: acc did not improve from 0.90438
# 4/4 [==============================] - 174s 45s/step - loss: 0.3269 - acc: 0.8845 - val_loss: 0.2099 - val_acc: 0.9091
# Epoch 11/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3194 - acc: 0.8845
# Epoch 11: acc did not improve from 0.90438
# 4/4 [==============================] - 174s 45s/step - loss: 0.3194 - acc: 0.8845 - val_loss: 0.2295 - val_acc: 0.9242
# Epoch 12/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2742 - acc: 0.8964
# Epoch 12: acc did not improve from 0.90438
# 4/4 [==============================] - 173s 45s/step - loss: 0.2742 - acc: 0.8964 - val_loss: 0.2213 - val_acc: 0.9242
# Epoch 13/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2489 - acc: 0.9163
# Epoch 13: acc improved from 0.90438 to 0.91633, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 174s 45s/step - loss: 0.2489 - acc: 0.9163 - val_loss: 0.2079 - val_acc: 0.9242
# Epoch 14/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2249 - acc: 0.9402
# Epoch 14: acc improved from 0.91633 to 0.94024, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 175s 45s/step - loss: 0.2249 - acc: 0.9402 - val_loss: 0.1925 - val_acc: 0.9242
# Epoch 15/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2482 - acc: 0.9044
# Epoch 15: acc did not improve from 0.94024
# 4/4 [==============================] - 174s 45s/step - loss: 0.2482 - acc: 0.9044 - val_loss: 0.1913 - val_acc: 0.9242
# Epoch 16/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2448 - acc: 0.9004
# Epoch 16: acc did not improve from 0.94024
# 4/4 [==============================] - 173s 45s/step - loss: 0.2448 - acc: 0.9004 - val_loss: 0.1873 - val_acc: 0.9242
# Epoch 17/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2652 - acc: 0.9124
# Epoch 17: acc did not improve from 0.94024
# 4/4 [==============================] - 172s 44s/step - loss: 0.2652 - acc: 0.9124 - val_loss: 0.1793 - val_acc: 0.9242
# Epoch 18/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2630 - acc: 0.8924
# Epoch 18: acc did not improve from 0.94024
# 4/4 [==============================] - 171s 45s/step - loss: 0.2630 - acc: 0.8924 - val_loss: 0.1863 - val_acc: 0.9242
# Epoch 19/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2449 - acc: 0.9044
# Epoch 19: acc did not improve from 0.94024
# 4/4 [==============================] - 171s 44s/step - loss: 0.2449 - acc: 0.9044 - val_loss: 0.1777 - val_acc: 0.9242
# Epoch 20/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2663 - acc: 0.9044
# Epoch 20: acc did not improve from 0.94024
# 4/4 [==============================] - 172s 45s/step - loss: 0.2663 - acc: 0.9044 - val_loss: 0.1834 - val_acc: 0.9394

# %%
train_result = model_vgg16.evaluate(train_generator)
test_result = model_vgg16.evaluate(test_generator)

augmented_df = pd.DataFrame(zip(train_result,test_result),columns=['Train','Val'],index=['Loss','Acc'])
augmented_df
# Out:
# 4/4 [==============================] - 136s 33s/step - loss: 0.1201 - acc: 0.9681
# 2/2 [==============================] - 35s 1s/step - loss: 0.1834 - acc: 0.9394
#          Train       Val
# Loss  0.120105  0.183441
# Acc   0.968127  0.939394

# %%
# Training confusion Matrix
ytrain = np.array([])
xtrain = []

for i in range(math.ceil(len(train_generator.classes)/batch_size)):
    xtrain.append(train_generator[i][0]) 
    ytrain= np.concatenate((ytrain,train_generator[i][-1])) 
    
xtrain = np.concatenate((xtrain),axis=0)

ypred_prob =model_vgg16.predict(xtrain)
ypred = np.argmax(ypred_prob,axis=1)

plt.figure(figsize=(6, 6))
hm = sns.heatmap(confusion_matrix(ytrain,ypred), annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False,
            xticklabels=['Normal','Viral Penumonia','Covid'],yticklabels=['Normal','Viral Penumonia','Covid'])  
hm.set(xlabel='Predicted_labels')
hm.set(ylabel='True_labels')
print(classification_report(ytrain,ypred))
# Out:
# 8/8 [==============================] - 125s 16s/step
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.97      0.94        70
#          1.0       0.97      0.93      0.95        70
#          2.0       1.00      0.99      1.00       111
#
#     accuracy                           0.97       251
#    macro avg       0.96      0.96      0.96       251
# weighted avg       0.97      0.97      0.97       251

# %%
# Testing Confusion Matrix
ytest = np.array([])
xtest = []

for i in range(math.ceil(len(test_generator.classes)/batch_size)):
    xtest.append(test_generator[i][0]) 
    ytest= np.concatenate((ytest,test_generator[i][-1])) 
    
xtest = np.concatenate((xtest),axis=0)

ypred_prob =model_vgg16.predict(xtest)
ypred = np.argmax(ypred_prob,axis=1)

plt.figure(figsize=(6, 6))
hm = sns.heatmap(confusion_matrix(ytest,ypred), annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False,
            xticklabels=['Normal','Viral Penumonia','Covid'],yticklabels=['Normal','Viral Penumonia','Covid'])  
hm.set(xlabel='Predicted_labels')
hm.set(ylabel='True_labels')
print(classification_report(ytest,ypred))
# Out:
# 3/3 [==============================] - 33s 8s/step
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.80      0.89        20
#          1.0       0.83      1.00      0.91        20
#          2.0       1.00      1.00      1.00        26
#
#     accuracy                           0.94        66
#    macro avg       0.94      0.93      0.93        66
# weighted avg       0.95      0.94      0.94        66
